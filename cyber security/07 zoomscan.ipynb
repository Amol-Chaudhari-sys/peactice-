# %%
apt insall zoomscan

# %%
drupal scaner

# %%
sql injection

# %%
inband sqli 
    1 error based sqli 
relise on error message 
thrown by the database server 
to obtain information 
about the structure of the database 

    2 union based sqli

# %%
inferential SQli

# %%
boolen based blind injection

# %%
time based blind injection

# %% [raw]
# sqli methodology
#
# understand website working
# search for parameters
# try to generate error and try to solve the error
# access db using tools

# %%
stored xss 
dom based xss 
reflected xss
