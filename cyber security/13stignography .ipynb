# %%
openstago 
send data through inage or diffrant formate

# %%
firewalls 
host based 
network based 
virtual based

# %%
deffence rules 
listed list 
white list

# %%
hashing technique 
sha1 
sha2 sha-256
md4
md5 
md6

# dictionary attack 
rainbow table
common words passwords  and their hash password
