# %%
blackhat

# %%
white hat
# Out:
#   Cell In[10], line 1
#     white hat
#           ^
# SyntaxError: invalid syntax

# %%
gray hat 
students elligal but dont cross limit

# %%
zero click  hacking new concept

# %%
in window hacking is possible but need to intall tools menualy

# %%
malware 

virus 
worm
trojan
ransomware      lock our files 
spyware          screenshort /key loger 
rootkit          hide betweet process and work on backgrount 

deleaver by
email attachment
usb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 malware
#
# NameError: name 'malware' is not defined

# %%
basic 
python 
java 
html 
js
sql

# %%
# bug bounty program

# %%
steps
creconnaissance 
explo
diffance

# %%
# who is 
website for explore the domain

# %%
wifi attack 





give the root permission

# %%
sudo su

# %%
tools

# %%
insall
# holehe
from git hub 

give information about no . also

# %%
# pwned 
website to see e mail id detail

# %%
# theHaevester 
github 
test walnab .com
practice hacking

# %%
leakclick   for password
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 leakclick
#
# NameError: name 'leakclick' is not defined

# %%
 # sharelock  
website And kali tool 
social media platform for perticular id 
with username

# %%
password cracking

# %%
methodes

# %%
# brute force 
try possible passwords 
diffrant combination

# %%
# phishings
 install  # bobscork 
# crunch
tool 

fake webpage /login page similar web 
user enter user name and password and its hacked 

 # zphisher 
tool install from github 
creating fake website

# %%
wifi

# %%
manage mode 
monitor mode

# %%
lsusb

# %%
aircrack -ng

# %%
wifi pishing
