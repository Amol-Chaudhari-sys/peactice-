# %%
pip install mobsf

# %%
mobsf

# %% [markdown]
# click on port no with ctrl for open in browser

# %% [markdown]
# drag and dropthen any application software for test

# %% [markdown]
# it will give the information about the system and give suggestion to make secure the system

# %% [markdown]
# # riquest response

# %% [markdown]
# '''riquest
# method of request
#
# get, clearly visibal data in url
#
# post, safe then get show data in inspect
#
# put , dangerious method allow to update data base user
#
# delete, dengerious method
#
# options,
#
# tress,
#
# connect,
#
# '''

# %% [markdown]
# for open the oprts like http
# linux -apachi 2
# windows -iis

# %%
ifconfig

# %%
service apache2 start

# %%
cd /var/www/html

# %%
gedit index.html

# %%
mkdir test

# %%
cd tast

# %%
mkdir test2

# %% [markdown]
# then go to browser and search 192.168.1.01/test

# %%
192.168.0.1/test

# %%
tempmail fakemail website

# %%
ngrok

# %%
pip install ngrok

# %%
ngrok login

# %%
ngrok authtoken pest token

# %%
nh kex passwd    #  nethunter

# %%
nh

# %%
sudo su

# %%
kex

# %%
install nethunter kex  install from browser
