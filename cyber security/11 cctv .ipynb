# %%
living strimign on the public ip 
1 cloud 
2 port forwording  (only one port) 
3 dmz  (multiple port )

# %%
network maping 
nmap 
1 host status
2 open port 
3 service 
4 sofware version 
5 os

# %%
nmap -sT 192.168.1.211   tcp scan
nmap -su    camere ip /vectum ip        udp scan
nmap -sS                   syn 
nmap -sA                 Ack
