# %% [markdown]
# ##apps update

# %%
apt update

# %% [markdown]
# #pakages updating

# %%
pkg update

# %% [markdown]
# #installing nmp

# %%
apt install nmap

# %% [markdown]
# #for checking ip addresses

# %%
ifconfig

# %% [markdown]
# #for scanning network in our id suppose our ip is 192.168.0.1 by defoult scann 1000 ports

# %%
nmap 192.168.0.0/24 -v

# %% [markdown]
# #check host is online or notscanning ports no port scan

# %%
nmap 192.168.0.0/24 -v -sn

# %% [markdown]
# #by selecting specific ip give command to check ports of specific ip

# %%
nmap 192.168.1.211 -v
