# %%
amanhardikar.com/mindmap/practical.html

# %%
tor browser 
orbot   for android

# %%
android apps for syber security 
netx    netwoek scanner
netcat for android      remote cantrol etc 
aflogical ose 
wifi inspect
virustotal
invisible pro
anlinux
