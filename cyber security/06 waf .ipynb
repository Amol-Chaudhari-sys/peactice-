# %%
web application firewalll

# %%
service apache2 start

# %%
apt install libapace2-mod -security2

# %%
cd /etc/modesecurity

# %%
gedit modesecurity.config
line no 7 
secruleengine on

# %%
service apache2 restart
