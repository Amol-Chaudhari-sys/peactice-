# %%
import numpy as np 
import pandas as pd

# %%
ar =np.array([1,4,2,76,9,87,45,87,56,23,56,76,87])
len(ar)
# Out:
# 13

# %%
sum(ar
# Out:
# 609

# %%
np.sum(ar)
# Out:
# 609

# %% [raw]
# mean=sum(ar)/len(ar)
# print (mean)

# %%
np.sum(ar)/len(ar)
# Out:
# 46.84615384615385
