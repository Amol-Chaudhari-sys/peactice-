# %% [raw]
# # Random variable

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# import matplotlib.pyplt as plt

# %% [raw]
# destint random variable  (1,2,3,4,5)
#
# continous random variable (1-2,2-3,3-4)

# %% [markdown]
# # Probability

# %% [raw]
# probability distrubrution function

# %% [raw]
# probability density functon(pdf ) : for continuous functions
# probability mass function (pmf)  : descontineus and repetative data
# comulative Density function (cdf) :  sum of less than no
#
# normal destrubrution : symmetric
# standard normal destrubrution : normal destrubrution with central alliment at origin and std division is 1

# %% [markdown]
# # covariance and corelation

# %% [raw]
# coveriance :
#      linear relationship
# cov (x,y)= sum {(x-X )*(y-Y)}/   -inf to +inf
#
# positive : both incresing or decresing
# negative : opposite
# zero :

# %% [raw]
# corelation :
#      corel(x,y)=cov (x,y)/sdt X*std y   -1 to 1

# %%
dataset=pd.read_csv("practice1.csv")
dataset1=pd.read_csv("airlines(in).csv")

# %%
dataset.info()
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Project Name   46 non-null     object
#  1   Task Name      46 non-null     object
#  2   Assigned to    46 non-null     object
#  3   Start Date     46 non-null     object
#  4   Days Required  46 non-null     int64
#  5   End Date       46 non-null     object
#  6   Progress       46 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 2.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4408 entries, 0 to 4407
# Data columns (total 24 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Airport.Code                                         4408 non-null   object
# ...

# %%
dataset1.head(5)
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
#
#    Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 0           6            June       2003                            1009
# 1           6            June       2003                             374
# 2           6            June       2003                             296
# 3           6            June       2003                             300
# 4           6            June       2003                             283
#
#    Statistics.# of Delays.Late Aircraft  \
# ...

# %%
data_cov=dataset1.select_dtypes(["int64","int64"]).cov()
data_cov
# Out:
#                                                      Time.Month     Time.Year  \
# Time.Month                                            11.957006     -0.963515
# Time.Year                                             -0.963515     13.450376
# Statistics.# of Delays.Carrier                        -9.971887    -81.240222
# Statistics.# of Delays.Late Aircraft                 -41.140339      0.767708
# Statistics.# of Delays.National Aviation System      -32.441785   -660.253840
# Statistics.# of Delays.Security                        0.922217     -6.947030
# Statistics.# of Delays.Weather                       -16.414902    -52.759181
# Statistics.Carriers.Total                              0.074953     -4.056932
# Statistics.Flights.Cancelled                        -132.837352    -49.741506
# Statistics.Flights.Delayed                           -99.098289   -800.310072
# Statistics.Flights.Diverted                           -1.218074     -0.690766
# ...

# %%
data_corr=dataset1.select_dtypes(["int64","int64"]).corr()
data_corr
# Out:
#                                                     Time.Month  Time.Year  \
# Time.Month                                            1.000000  -0.075977
# Time.Year                                            -0.075977   1.000000
# Statistics.# of Delays.Carrier                       -0.008749  -0.067204
# Statistics.# of Delays.Late Aircraft                 -0.021178   0.000373
# Statistics.# of Delays.National Aviation System      -0.010177  -0.195279
# Statistics.# of Delays.Security                       0.044398  -0.315334
# Statistics.# of Delays.Weather                       -0.063141  -0.191346
# Statistics.Carriers.Total                             0.009466  -0.483083
# Statistics.Flights.Cancelled                         -0.132985  -0.046951
# Statistics.Flights.Delayed                           -0.016750  -0.127542
# Statistics.Flights.Diverted                          -0.009689  -0.005181
# Statistics.Flights.On Time                            0.024357  -0.052625
# ...

# %%
sns.heatmap(data_corr,annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(data_cov,annot=True)
# Out:
# <Axes: >
