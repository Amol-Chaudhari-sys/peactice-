# %%
a=1 
b="amol"
c=9.2
print (a )
print (b )
print (c)
# Out:
# 1
# amol
# 9.2

# %% [markdown]
# # assignment opprator

# %%
a=1+2
a+=3
print (a)
a==6
# Out:
# 6
# True

# %% [markdown]
# # logical operator

# %%
e=True and  False
print (e)
f=True or False 
print (f)

#truth table 
print ("Trur or False is ",True or False )
print ("Trur or True is ",True or True  )
print ("False or False is ",False or False )
print ("False or True is ",False or True  )

# truth table for and 
print ("True and  False is ",True and  False )
print ("True and  True is ",True and  True  )
print ("False and  False is ",False and  False )
print ("False and  True is ",False and  True  )

print (not(f))
# Out:
# False
# True
# Trur or False is  True
# Trur or True is  True
# False or False is  False
# False or True is  True
# True and  False is  False
# True and  True is  True
# False and  False is  False
# False and  True is  False
# False

# %% [markdown]
# # Type casting

# %%
a=float (input ("inter the number "))
print (type (a))
b=float(a)
print (type (b),b)
c= int (b)
print (c)
# Out:
# inter the number  58.2
# <class 'float'>
# <class 'float'> 58.2
# 58

# %%
a=int (input("Enter the no a :"))
b=int (input("enter the no b"))
print (a+b)
# Out:
# Enter the no a : 2
# enter the no b 6
# 8

# %%
a=int (input ("enter the no" ))
b=int (input("enter the no b "))
print ("reminder of  a divided by b is ", a%b)
# Out:
# enter the no 57
# enter the no b  2
# reminder of  a divided by b is  1

# %%
t=input("enter any thing :")
b= (type(t))
print (b)
# Out:
# enter any thing : 5.4
# <class 'str'>

# %%
a=int(input ("Enter no a"))
b=int (input ("Enter no b :"))
if (a>=b): 
    print ("a is grater ")
else: print ("b is grater ")
# Out:
# Enter no a 56
# Enter no b : 87
# b is grater

# %%
a=int(input ("Enter no a"))
b=int (input ("Enter no b :"))
print ("Average is :",(a+b)/2)
# Out:
# Enter no a 3
# Enter no b : 6
# Average is : 4.5

# %%
a=(input ("Enter no a"))
b=float(a)
print (b)
# print ("the square of the no. is :",a*a)
print (type (b))
# Out:
# Enter no a 31
# 31.0
# <class 'float'>
