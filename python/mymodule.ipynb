# %%
def myfun():
    print ("this is my function of mudule ")

myfun()  
print (__name__)

if __name__ =="__main__":
    print ("this function running in this file and not imported ")
# Out:
# this is my function of mudule
# __main__
# this function running in this file and not imported

# %%
# Out:
# 3
# 3

# %%
# Out:
# item number it index 0 is 1
# item number it index 1 is 2
# item number it index 2 is 4
# item number it index 3 is 6
# item number it index 4 is 5
# item number it index 5 is 897
# item number it index 6 is 980
# item number it index 7 is 90

# %%
# Out:
# [1, 4, 9, 16, 25, 36, 49]
# [1, 4, 9, 16, 25, 36, 49]
