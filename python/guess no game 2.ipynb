# %%
import random 
a=random.randint(1,100)
guess= 0
n=int (input ("Enter the no : "))

while (a!=n):
    
    n=int (input ("Enter the no : "))
    if (n>a):
        print ("enter thr small no ")
        guess+=1
    elif (a>n):
        print ("Enter the greaer no ")
        guess+=1
print (f"you win in the {guess} attempte")
# Out:
# Enter the no :  50
# Enter the no :  50
# enter thr small no
# Enter the no :  25
# enter thr small no
# Enter the no :  15
# Enter the greaer no
# Enter the no :  20
# enter thr small no
# Enter the no :  17
# Enter the greaer no
# Enter the no :  19
# you win in the 5 attempte
