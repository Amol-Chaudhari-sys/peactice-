# %% [markdown]
# # Dictionary

# %%
marks ={
    "amol":97,
    "wara":99,
    "cha":54,
    0:"swan"
}
len(marks)
# Out:
# 4

# %%
print (marks.keys())
print (marks.values())
print (marks.items())
marks.update({"wara":100})
marks.update({"sai":99})
print (marks)
print(marks .get ("wara"))
# Out:
# dict_keys(['amol', 'wara', 'cha', 0, 'sai'])
# dict_values([97, 100, 54, 'swan', 99])
# dict_items([('amol', 97), ('wara', 100), ('cha', 54), (0, 'swan'), ('sai', 99)])
# {'amol': 97, 'wara': 100, 'cha': 54, 0: 'swan', 'sai': 99}
# 100

# %% [markdown]
# # set

# %%
a= {1,4,5,7,2,2,2}
b={}  # empty dictionary 
c=set ()  # empty set

# %%
print (a)
len (a)
# Out:
# {1, 2, 4, 5, 7}
# 5

# %%
a.remove (2)

# %%
a.pop()
# Out:
# 1

# %%
print (a.union ({8,9,7}))  # s1.union(s2)
print (a.intersection({8,9,7}))
a.clear()
# Out:
# {4, 5, 7, 8, 9}
# {7}

# %%
a
# Out:
# set()

# %% [markdown]
# # Questions

# %%
Dict ={
    "madad ": "help ",
    "manjar":"cat ",
    "zad": "tree "
}
men =input ("n=Enter the word and get meaning :")

print (Dict[men])
# Out:
# n=Enter the word and get meaning : zad
# tree

# %%
s=set()
n=input ("enter the no : ")
s.add(int (n))
n=input ("enter the no : ")
s.add(int (n))
n=input ("enter the no : ")
s.add(int (n))
n=input ("enter the no : ")
s.add(int (n))
n=input ("enter the no : ")
s.add(int (n))
n=input ("enter the no : ")
s.add(int (n))
n=input ("enter the no : ")
s.add(int (n))

s.add("amol")

s
# Out:
# enter the no :  32
# enter the no :  13
# enter the no :  4
# enter the no :  6
# enter the no :  8
# enter the no :  6
# enter the no :  4
# {13, 32, 4, 6, 8, 'amol'}
