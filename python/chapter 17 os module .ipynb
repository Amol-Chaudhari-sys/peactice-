# %%
import os 

os.mkdir("osmodule")

# %%
for i in range(0,100):
    os.mkdir(f"osmodule/day{i}")

# %%
for i in range (0,100):
    os.rename(f"osmodule/day{i}", f"osmodule/module{i}")

# %%
for i in range (0,100):
    os.rename( f"osmodule/module{i}",f"osmodule/Tutorial{i+1}")

# %%
cd "osmodule"
# Out:
# C:\Users\HP\Desktop\E playlist\python\osmodule

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 88A9-F36E
#
#  Directory of C:\Users\HP\Desktop\E playlist\python\osmodule
#
# 01/17/2026  07:24 PM    <DIR>          .
# 01/17/2026  07:24 PM    <DIR>          ..
# 01/17/2026  07:16 PM    <DIR>          Tutorial1
# 01/17/2026  07:16 PM    <DIR>          Tutorial10
# 01/17/2026  07:16 PM    <DIR>          Tutorial100
# 01/17/2026  07:16 PM    <DIR>          Tutorial11
# 01/17/2026  07:16 PM    <DIR>          Tutorial12
# 01/17/2026  07:16 PM    <DIR>          Tutorial13
# 01/17/2026  07:16 PM    <DIR>          Tutorial14
# 01/17/2026  07:16 PM    <DIR>          Tutorial15
# 01/17/2026  07:16 PM    <DIR>          Tutorial16
# 01/17/2026  07:16 PM    <DIR>          Tutorial17
# 01/17/2026  07:16 PM    <DIR>          Tutorial18
# 01/17/2026  07:16 PM    <DIR>          Tutorial19
# 01/17/2026  07:30 PM    <DIR>          Tutorial2
# 01/17/2026  07:16 PM    <DIR>          Tutorial20
# ...

# %%
list = os.listdir("osmodule")
for i in list:
    print (i)
    print (os.listdir(f"osmodule/{i}"))
# Out:
# Tutorial1
# []
# Tutorial10
# []
# Tutorial100
# []
# Tutorial11
# []
# Tutorial12
# []
# Tutorial13
# []
# Tutorial14
# []
# Tutorial15
# []
# Tutorial16
# []
# Tutorial17
# []
# Tutorial18
# []
# Tutorial19
# []
# Tutorial2
# ['file2.1.txt']
# Tutorial20
# []
# Tutorial21
# []
# Tutorial22
# []
# Tutorial23
# []
# Tutorial24
# []
# Tutorial25
# []
# Tutorial26
# []
# Tutorial27
# []
# Tutorial28
# []
# Tutorial29
# []
# Tutorial3
# []
# Tutorial30
# []
# Tutorial31
# []
# Tutorial32
# []
# Tutorial33
# []
# Tutorial34
# []
# Tutorial35
# []
# Tutorial36
# []
# Tutorial37
# []
# Tutorial38
# []
# Tutorial39
# []
# Tutorial4
# []
# Tutorial40
# []
# Tutorial41
# []
# Tutorial42
# []
# Tutorial43
# []
# Tutorial44
# []
# Tutorial45
# []
# Tutorial46
# []
# Tutorial47
# []
# Tutorial48
# []
# Tutorial49
# []
# Tutorial5
# []
# Tutorial50
# []
# Tutorial51
# []
# Tutorial52
# []
# Tutorial53
# []
# Tutorial54
# []
# Tutorial55
# []
# Tutorial56
# []
# Tutorial57
# []
# Tutorial58
# []
# ...

# %%
cd ..
# Out:
# C:\Users\HP\Desktop\E playlist\python

# %%
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Desktop\\E playlist\\python\\osmodule'

# %%
os.chdir("osmodule")

# %%
cd ..
# Out:
# C:\Users\HP\Desktop\E playlist\python

# %%
import os
list=os.listdir("osmodule")
for i,name in enumerate (list,start =1 ):
    os.rename(f"osmodule/{name}",f"osmodule/module {i} ")

# %%
list
# Out:
# ['Tutorial10',
#  'Tutorial100',
#  'Tutorial11',
#  'Tutorial12',
#  'Tutorial13',
#  'Tutorial14',
#  'Tutorial15',
#  'Tutorial16',
#  'Tutorial17',
#  'Tutorial18',
#  'Tutorial19',
#  'Tutorial2',
#  'Tutorial20',
#  'Tutorial21',
#  'Tutorial22',
#  'Tutorial23',
#  'Tutorial24',
#  'Tutorial25',
#  'Tutorial26',
#  'Tutorial27',
#  'Tutorial28',
#  'Tutorial29',
#  'Tutorial3',
#  'Tutorial30',
#  'Tutorial31',
#  'Tutorial32',
#  'Tutorial33',
#  'Tutorial34',
#  'Tutorial35',
#  'Tutorial36',
#  'Tutorial37',
#  'Tutorial38',
#  'Tutorial39',
#  'Tutorial4',
#  'Tutorial40',
#  'Tutorial41',
#  'Tutorial42',
#  'Tutorial43',
#  'Tutorial44',
#  'Tutorial45',
#  'Tutorial46',
#  'Tutorial47',
#  'Tutorial48',
#  'Tutorial49',
#  'Tutorial5',
#  'Tutorial50',
#  'Tutorial51',
#  'Tutorial52',
#  'Tutorial53',
#  'Tutorial54',
#  'Tutorial55',
#  'Tutorial56',
#  'Tutorial57',
#  'Tutorial58',
#  'Tutorial59',
#  'Tutorial6',
#  'Tutorial60',
#  'Tutorial61',
#  'Tutorial62',
# ...
