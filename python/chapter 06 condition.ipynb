# %%
a=int (input ("Enter the age : "))
if (a%2==0):
    print ("even")
if (a>18):
    print ("adult")

elif(a<0):print ("you enterd invalid no")

else : 
    print ("child" )
print ("good morning ")
# Out:
# Enter the age :  13
# child
# good morning

# %% [markdown]
# # questions

# %%
a1=int (input ("Enter the no 1"))
a2=int (input ("Enter the no 2"))
a3=int (input ("Enter the no 3"))
a4=int (input ("Enter the no 4"))

if (a1>a2 and a1>a3 and a1>a4):
    print (f'{a1} is grater')
elif (a2>a1 and a2>a3 and a2>a4):
    print (f'{a2} is grater')
elif (a3>a2 and a3>a1 and a3>a4):
    print (f'{a3} is grater')
else:
    print (f"{a4} is grater ")
# Out:
# Enter the no 1 13
# Enter the no 2 14
# Enter the no 3 15
# Enter the no 4 12
# 15 is grater

# %%
m1=int (input ("Marks of subject 1" ))
m2=int (input ("Marks of subject 1" ))
m3=int (input ("Marks of subject 1" ))
avg =(m1+m2+m3)/3

if (m1>=33 and m2>=33 and m3>=33 and avg>=40):
    print ("pass ")
elif (m1 <0 or m2<0 or m3 < 0 ):
    print ("invalid marks ")
else: print ("fail ")
# Out:
# Marks of subject 1 33
# Marks of subject 1 33
# Marks of subject 1 33
# fail

# %%
p1="make lots of money"
p2="buy now"
p3="sbuscribe this"
p4 ="click this"

message =input (" Enter the message :")

if (p1 in message.lower() or p2 in message.lower() or p3 in message.lower() or p4 in message.lower()  ):
    print ("spam detcted ")

else : print ("safe ")
# Out:
#  Enter the message : AMOL CHAUDHARI CLICK THIS
# spam detcted

# %%
uname = input (" Enter the user name ")
if (len(uname<10):
    print ("your username contain less then 10 letters ")

else : print ("ok ")
# Out:
#  Enter the user name  amolchaudhari
# ok
