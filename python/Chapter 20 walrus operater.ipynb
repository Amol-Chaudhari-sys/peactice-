# %%
a=True
print (a:=False)
# Out:
# False

# %%
num =[12,23,45,12,6,8,9,4]
while (n:=len(num) >0):
    print (num.pop())
# Out:
# 4
# 9
# 8
# 6
# 12
# 45
# 23
# 12

# %%
foods =list()
while True:
    food = input("enter food ")
    if food =="quit":
        break
    else :
        foods.append (food)
# Out:
# enter food  mango
# enter food  apple
# enter food  orange
# enter food  pineapple
# enter food  sitaphal
# enter food  graphs
# enter food  quit

# %%
ani=list ()
while (pet :=input ("enter favourite  pet animal name ") ) !="quite":
    
    ani.append(pet)
# Out:
# enter favourite  pet animal name  cat
# enter favourite  pet animal name  dog
# enter favourite  pet animal name  bird
# enter favourite  pet animal name  kitti
# enter favourite  pet animal name  puppy
# enter favourite  pet animal name  quit
# enter favourite  pet animal name  quit
# enter favourite  pet animal name  quite

# %%
print (ani)
# Out:
# ['cat', 'dog', 'bird ', 'kitti ', 'puppy ', 'quit ', 'quit']
