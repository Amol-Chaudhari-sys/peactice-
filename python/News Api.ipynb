# %%
import requests
import json

# %%
query =("which type of news you want ")
url = f"https://newsapi.org/v2/everything?q={query}&from=2026-01-27&sortBy-publishedAt&apiKey=dbe57b028aeb41e285a226a94865f7a7"
r= requests.get(url)
news = json.loads(r.text)
# for article in news["articles"]:
#     print (article["tile"])
#     print (article["description"])

# %%
print (r.text)
# Out:
# {"status":"error","code":"rateLimited","message":"You have made too many requests recently. Developer accounts are limited to 100 requests over a 24 hour period (50 requests available every 12 hours). Please upgrade to a paid plan if you need more requests."}

# %%
# news api login
