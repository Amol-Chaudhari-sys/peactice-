# %%
social engineering tool kit 
create fake clone website for phishing

gophish          https://getgophish.com/
open source phishing framework

hash key 

firewalls

Packet filtering fire wall : all udp flows and telnet conections are bolcked 


Cryptography 

cryptographic attack
1. brutforce attack
2.rainbow tabel 
3.social engineering
4.known plain taxt 
5.known chippertaxt

language of cryptography
