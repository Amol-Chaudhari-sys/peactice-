# %%
basic 
defination 
1computer forensics
2 mobile device forensics 
3network forensic 
4cloud forensics 

low and regulatoons 
avidance handling procedure

# %%
essential skill 
understand os 
knowledge of file 
network fundamental 
programming basics 
ethical hacking 
understand encription and data recovery

# %%
softskill 
analitical thing 
attention of detail 
problem solving skill

# %%
learning 
google search 
github repo 
online news letters and bolgs 
books 
    computer forensics cybercriminals ,laws and avidances 
    digital forensics fo rdummies 
    practical digital forensics 
tools 
    ecase
    ftk (forensic toolkit )
    autopsy /sleuth kit 
    Wireshark

# %%
practice 
setting up lab 
solving challanges 
participationg in CTFs

# %%
phishing 
smishing 
vishing 
fakewebsite 
impersonation  scams or confidance fraud  
skimming
