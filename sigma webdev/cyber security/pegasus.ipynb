# %%
kali 10 tools 
SET   (social engineering toolkit )
wireshark 
zaproxy
sqlmap
aircrack-ng
burp suit
nmap
nicto
metasploit
netcat

# %%
hardware devices 
usb rubber ducky 
usb killer 
raspberry  pi
ardino chip 
proxmark3

# %%
websites 
seachdns.netcraft.com
nmmapper.com 
web-check.xyz

# %%
ai search engine 
andisearch
