# %% [markdown]
# #use vmwave or virtualbox for creating virtual machine

# %% [markdown]
# #giving root permition to the system

# %%
sudo su

# %% [markdown]
# #for checking the internate connection

# %%
ping google.com

# %% [markdown]
# #for reconnecting to network properly

# %%
service NetworkManager restart

# %% [markdown]
# #for updating packages present in system

# %%
cd /etc/apt

# %%
ls

# %% [markdown]
# #modify the file sorces.list

# %%
gedit sources.list

# %% [markdown]
# #modify it by uncomment the line
# #additional line for source
# deb-src http ..........firmware
# then close the file

# %%
apt update

# %% [markdown]
# #changing hostname

# %%
gedit /etc/hostname

# %%
gedit /etc/hosts
