# %%
sudo su

# %%
apt update

# %% [markdown]
# it upgrate all tools present in the system

# %%
apt upgrate

# %% [markdown]
# #write a half name then pres tab for checkng like names of tools or softwares

# %%
apt install bytecode-viewer

# %%
if softwares not working properly install it by

# %%
apt reinstall ytecode-viewer

# %% [markdown]
# for installing downloaded softwaresfrom browser or apk files

# %% [markdown]
# go to the folder where downloaded file is present by cd command

# %%
cd downloads

# %% [markdown]
# downloaded file should be .deb formate debial formate dpkg debial package managing tool

# %%
dpkg -i google-chrome-stable_current_amd64\(4\).deb

# %% [markdown]
# for deleting file from device

# %%
rm -r filename
