# %%
apt install libapachi2-mod-security2

# %%
# owasp
mode security rools    web applcation firewall

# %%
git clone
for gihub installation

# %%
move code from

# %%
cp rules /etc/modsecurity

# %%
cp crs-setup.conf.example /etc/modsecurity

# %%
remame some files

# %%
mv crs-setup.conf.example crs-setup.conf

# %%
cd /etc/apache2

# %%
cd mods-enabled
