# %%
webapplications hackers handbook  filetype:pdf 
bugbounty hunting essentials

# %%
velnhub practice platform

# %%
kloptrix  serien eassy hack 
empire 
darkhole

# %%
wargames bandit

# %%
hackthissite

# %%
bugbounty platform 
hackerone 
bugcroud

# %%
hach the box  paid platform

# %%
evernote 
cherry tree 
for docuentation
