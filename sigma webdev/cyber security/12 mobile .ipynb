# %%
1 milicious attacks in store 
2 mobile malware 
3 appsand box valnabarities 
4 weak device and app encription 
5 os and app update issue 
6 jail breaking and rooting 
7 weak data security 
8 mobile application valba]nabarity 
privacy issue geolocation

# %%
woasp

# %%
emaluter 
termux  install from f droid 
bashshell online 
online terminal for lerarning commands

# %%
nmap 
fing 
network mapper 
vnc terminal

# %%
top 5 tools 
1 mspy      remote accessing tool 
2 eyezy      
3 clevguard        
4 flexispy     monetoring 
5 umobix

# %%
tools for android security 
adb android debugging bridge 
apk signer 
aptool
mobsf    mobile security framework 
mvt mobile verification tool  install from git hub 

mobsf.live

# %%
mvt install from git hub 


mvt-android 
mvt-android download-iocs

# %%
virustotal.com

# %%
kali nackhunter

# %%
apt install wget

# %%
wget -O install https://offs.ec/2MceZWr     for install kali hunter in termux

# %%
chmod +x install

# %%
./install
